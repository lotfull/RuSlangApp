# %%
# coding=utf-8
import numpy
import os
import pandas as pd
import csv
import sqlite3 as lite
from bs4 import BeautifulSoup
from selenium import webdriver
from shutil import copyfile
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-43311e1b9d76> in <module>()
#       1 # coding=utf-8
# ----> 2 import numpy
#       3 import os
#       4 import pandas as pd
#       5 import csv
#
# ModuleNotFoundError: No module named 'numpy'

# %%
def Text_from_html_object(text):
    start = text.find("<")
    finish = text.find(">")
    text = text[:start] + text[finish + 1:]
    check_for_tag = text.find('<', start)
    while check_for_tag != -1:
            end_of_tag = text.find('>', check_for_tag)
            text = text[:check_for_tag] + text[end_of_tag + 1:]
            check_for_tag = text.find('<', check_for_tag)
    return text

def Text_from_html_arr(arr):
    answer_text = ''
    for object in arr:
        text = str(object)
        check_for_tag = text.find('<')
        while check_for_tag != -1:
            end_of_tag = text.find('>', check_for_tag)
            text = text[:check_for_tag] + text[end_of_tag + 1:]
            check_for_tag = text.find('<', check_for_tag)
        answer_text += text
    return answer_text

def get_page_count(soup):
    list_of_pages = soup.find_all('a', class_='page_number')
    try:
        last_page = list_of_pages[-2]
    except IndexError:
        return 1
    last_number = Text_from_html_object(str(last_page))
    return int(last_number)

def take_rus_letters_numbers(soup):
    links = []
    list_of_links = soup.find_all('a', class_='alph_menu')
    for link in list_of_links:
        pos = int(str(link).find("%D0%")) + 4
        name = str(str(link)[pos:pos+2])
        if name != "81":
            links.append(name)
    return links

def make_save(path):
    with open(path, 'w') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(('name', 'type', 'group', 'definition', 'examples', 'hashtags', 'story', 'synonims'))

def add_to_save(dict, path):
    with open(path, 'a') as csvfile:
        writer = csv.writer(csvfile)
        for word in dict:
            writer.writerow((word['name'], word['meaning'], word['type'], word['group'], 
                             word['example'], word['story'], word['hashtag'], word['synonims']))
            

    
# and then rename mycsv.out to mycsv.csv if you wish.

def get_word_from_to_path(from_i, to, filename):
    for j in range(from_i, to + 1):
    #for j in range(1, len(links)):
        path = filename + str(j) + '.csv'
        make_save(path)
        driver.get('http://teenslang.su/content/%D0%'+ rus_letters_numbers[j]) # download site to the Selenium
        html = driver.page_source # saving site source
        soup = BeautifulSoup(html, "lxml")
        page_count = get_page_count(soup)
        print('Буква алфавита № ' + str(j + 1) + ': ')
        dict = []
        for i in range(page_count):
            if i > 0:
                driver.get('http://teenslang.su/?page=' + str(i) + '&content=%D0%'+ rus_letters_numbers[j] + '*') # load sites
                html = driver.page_source # saving site source
                soup = BeautifulSoup(html, "lxml")
            print('Парсинг %d из %d' % (i + 1, page_count))
            table = soup.find('div', class_='visible-xs visible-md visible-sm visible-lg col-lg-6')
            words = table.find_all('div', class_='issueword1')

            for word_row in words:
                word_name = Text_from_html_object(str(word_row.find('span', class_='cap')))
                word_type = Text_from_html_object(str(word_row.find('span', class_='sta')))
                word_group = Text_from_html_object(str(word_row.find('span', class_='sph')))
                word_def = Text_from_html_object(str(word_row.find('span', class_='mea')))
                word_example = Text_from_html_object(str(word_row.find('span', class_='text')))
                word_story = Text_from_html_arr(word_row.find_all('div', class_='category'))
                word_hash = Text_from_html_object(str(word_row.find('span', class_='src')))
                word_syn = Text_from_html_object(str(word_row.find('span', class_='syn')))
                dict.append({
                    'num': i,
                    'name': word_name,
                    'type': word_type,
                    'group': word_group,
                    'meaning': word_def,
                    'example': word_example,
                    'story': word_story,
                    'hashtag': word_hash,
                    'synonims': word_syn
                })
        add_to_save(dict, path)
    print("!!!!!!!!!!!ВСЕ!!!!!!!!!!")
            
        
def get_rus_letters_numbers():
    driver = webdriver.PhantomJS()
    driver.get("http://teenslang.su/content/%D0%90")
    html = driver.page_source # saving site source
    soup = BeautifulSoup(html, "lxml")
    rus_letters_numbers = take_rus_letters_numbers(soup)
    return rus_letters_numbers

# %%
rus_letters_numbers = get_rus_letters_numbers()

# %%
filename = "dict"

# %%
get_word_from_to_path(from_i=9, to=9, filename=filename)

# %%
csvs_path = "/Users/lotfull/parsing/dicts/"

# %%
frames = []
for i in range(0, 32):
    frames.append(pd.read_csv(csvs_path + "dict" + str(i) + ".csv"))

# %%
result = pd.concat(frames)

# %%
result.columns.values[7] = 'synonyms'

# %%
result.to_csv("fullDict.csv", sep=',', index=False)

# %%
fulldict = pd.read_csv("fullDict.csv")
a = 679
fulldict[a:a + 3]
# Out:
#        name           definition        type        group  \
# 679    ахчи             девушка.       ж.р.   (армянский)
# 680  Б-база  база для курения Б.  сущь.м.р.     (курение)
# 681  Б-база   Женское общежитие.  сущ., ж.р    (студенты)
#
#                                               examples     hashtags  \
# 679                                            NonNone      #Общие
# 680               \nБ-база\nБ-база\nБ-база\nБ-база\n\n  #Наркоманы
# 681  Сегодня рулим на Б-Базу жрать и @бать. Лень го...      #Общие
#
#                                   story synonyms
# 679                             NonNone  NonNone
# 680                             NonNone  NonNone
# 681  от исконно-русского слова "Бл%дь".     ЦПХ.

# %%
fulldict.drop_duplicates(keep='first')
# Out:
#                       name                                         definition  \
# 0      А сегодня я покакал  Предложение, показывающие безразличие к тому ч...
# 1                     А то                      да — выражения подтверждения.
# 2                    Абаля                                   вот это конфуз!.
# 3                 Абанамат             восклицание раздражения или удивления.
# 4                   Абапер                       программист на языке ABAP/4.
# 5                 Абассака                      коммент к смешному креатиффу.
# 6                  абгрейд  АПГРЕ́ЙД\n1.Модернизация компьютера, обновлени...
# 7                    абдул                                   Обзывание хачей.
# 8                    абдул                            Мужское кавказское имя.
# 9                 аберглау                           Просто ляпнул - и забыл.
# 10                   Абзац     (предикатив) оценка ситуации как очень плохой.
# 11                Абздольц     (предикатив) оценка ситуации как очень плохой.
# 12                  Абибас  одежда - подделка под фирму «Adidas» с лейблом...
# 13                    Абик                                         абонемент.
# 14                   Абила    Активный навык, используемый персонажем в игре.
# 15                  абилка  Способность, полученная при прохождении компью...
# 16                 Абитура  абитуриенты, люди, поступающие в учебное завед...
# 17                 Абитуха  абитуриенты, совокупность всех поступающих в вуз.
# 18                Абориген                                    местный житель.
# 19                   Абрек  кавказец, выходец с Кавказа; но иногда в смысл...
# 20                  абсурд                            нелепость, бессмыслица.
# 21                   Абуба  Прозвище главного героя игры «DRAMAtical Murde...
# 22                 абузить  В Доте 2 под этим значением подразумевают испо...
# 23                абуминог                   Оскорбление, унижение, насмешка.
# 24                  Абуэма         Знак приветствия среди узкого круга людей.
# 25                    абыр                   Бессмысленная отрыжка блевотины.
# 26                 абьюзер  человек который выходит за рамки допустимого в...
# 27                      АВ  Abyss Walker, персонаж «Lineage 2» со второй п...
# 28                     Ава         доспех Авадон (Avadon) в игре «Lineage 2».
# 29                     Ава  картинка «лица» на форуме или блоге, подробнее...
# ...                    ...                                                ...
# 17818                 ЯнГо  Видеоблогер, на данный момент 3,1 млн подписчи...
# 17819               яндекс                                         поисковик.
# 17820               Яндере  один из типовых вариантов характера персонажа ...
# 17821               Яндере  Манера поведения, основанная на переходе от ми...
# 17822            яндеричка  обозначение психически неуравновешенного аниме...
# 17823            Яндэр бой  Изначально очень нежный и любящий человек, влю...
# 17824                Яникс                                         Бог трэпа.
# 17825               Яниксы         Фанат ЯнГо (Яна Гордиенко - видеоблогера).
# 17826                 янки  Представитель Американской державы,которого пы...
# 17827                 ЯННП                                 Я Ничего Не Понял.
# 17828                  Яой  Один из жанров аниме и манги  рассчитанный в о...
# 17829              яойщица  девушка, создающая романтические и/или сексуал...
# 17830              яойщицы                            анимешники, фикрайтеры.
# 17831               япвдул  одобрительный отзыв о красивой, сексапильной д...
# 17832                  Япи  богатый молодой человек, карьерист, подробнее ...
# 17833             Яплакалъ  смеялся до слез, оценка ситуациия как очень см...
# 17834          Япона  мать                          возглас выражения эмоций.
# 17835                 Яппи  возникший в США во время президентства Рональд...
# 17836                 Ярик                                   город Ярославль.
# 17837                 Ярко                                   хорошо, красиво.
# 17838            Ярославль                                       1000 рублей.
# 17839            Ясен пень               понятно, ясно, естественно, конечно.
# 17840         Ясен пень!!!                                       разумеется!.
# 17841           Ясень-пень       Когда наконец понял и говоришь "ясень-пень".
# 17842                 Ясмп  абсурдистская субкультура вокруг сайта  yasmp....
# 17843                 Ясмп                                 Я Сарт, Мне Похуй.
# 17844          яснапонятно                           Ясно , Понятно , Понял .
# 17845                 Ясно                             Ясно - значит понятно.
# 17846          яснопонятно                                 Ничего не понятно.
# 17847          Ясный перец         естественно, очевидно, полностью согласен.
#
#                                        type  \
# 0                           словосочетание
# 1                            союз и частица
# 2                                   NonNone
# 3                                междометие
# 4                                   -а, м.
# 5                                   -и, ж.
# 6                        Мужской род спец.
# 7                                  сущ.м.р
# 8                                   NonNone
# 9                          Существительное
# 10                                   -а, м.
# 11                                  NonNone
# 12                                  -а, м.
# 13                                   -а, м.
# 14             Существительное мужской род
# 15                              сущ., ж.р.
# 16                                  -е, ж.
# 17                                  -и, ж.
# 18                                  -а, м.
# 19                                  -а, м.
# 20                                  NonNone
# 21                              сущ., м.р.
# 22                                     гл.
# 23                             сущ., м. р.
# 24                         Существительное
# 25                               Междометие
# 26                               сущ., м.р
# 27                                 аббрев.
# 28                                  -ы, ж.
# 29                                  -ы, ж.
# ...                                     ...
# 17818                          сущ., м. р.
# 17819                            сущ., м.р.
# 17820                               нескл.
# 17821                      Существительное
# 17822                               NonNone
# 17823                           сущ., м.р.
# 17824                          сущ., м. р.
# 17825                          Сущ. Мн. ч.
# 17826  Существительное,множественное число
# 17827                              аббрев.
# 17828                            сущ.,с.р.
# 17829                         сущ., мн. ч.
# 17830                            сущ., ж.р.
# 17831                                глагол
# 17832                               NonNone
# 17833           в знач. нареч.и предикатив
# 17834                            междометие
# 17835                               NonNone
# 17836                               -а, м.
# 17837                                нареч.
# 17838                                    м.
# 17839                               NonNone
# 17840                               NonNone
# 17841                             сущ.,м.р
# 17842                               -а, м.
# 17843                           предикатив
# 17844                               NonNone
# 17845                             Наречие.
# 17846                               NonNone
# 17847                               NonNone
#
#                                                    group  \
# 0                               (Анонимы, тролли, хикки)
# 1                                                NonNone
# 2                                                NonNone
# 3                                                NonNone
# 4                                 (айтишники\n, прогеры)
# 5                                              (каменты)
# 6                                                   (IT)
# 7                                                 (хачи)
# 8                                                NonNone
# 9                                             (По всюду)
# 10                                               NonNone
# 11                                               NonNone
# 12                                             (гопники)
# 13                                               NonNone
# 14                                             (геймеры)
# 15                                             (гемейры)
# 16                                            (студенты)
# 17                                            (студенты)
# 18                            (спорт. туристы, ролевики)
# 19                                             (бонхеды)
# 20                                               NonNone
# 21                                        (анимудрочеры)
# 22                                       (игры, геймеры)
# 23                                              (жаргон)
# 24                                        (Модные парни)
# 25                                               NonNone
# 26                                            (интернет)
# 27                               (геймеры, РПГ, Линейка)
# 28                               (геймеры, РПГ, Линейка)
# 29                                            (интернет)
# ...                                                  ...
# 17818                                          (YouTube)
# 17819                                            NonNone
# 17820                                            (аниме)
# 17821                                            (Аниме)
# 17822                              (анимешники,геймер�.)
# 17823                                       (Извращенец)
# 17824                                        (Трэп хата)
# 17825                                           (Фанаты)
# 17826                             (политика,оскорбление)
# 17827                                         (интернет)
# 17828                                            (аниме)
# 17829                                       (анимешники)
# 17830                                            NonNone
# 17831                                            NonNone
# 17832                                            NonNone
# 17833                                (интернет, каменты)
# 17834                                            NonNone
# 17835                                            NonNone
# 17836                                          (топоним)
# 17837                                            NonNone
# 17838                                            NonNone
# 17839                                            NonNone
# 17840                                            NonNone
# 17841                                              (Все)
# 17842                                         (интернет)
# 17843                                         (Интернет)
# 17844                                            NonNone
# 17845  (Слово "ясно" употребляют когда человеку понят...
# 17846                                        (Молодежь.)
# 17847                                            NonNone
#
#                                                 examples  \
# 0      -Где можно обсудить проблемы кишечника?\n-В /p...
# 1                 — Ты знаешь такого чела...? — А то!!!
# 2                                                NonNone
# 3      Абанамат!!! Холодильник сломался не вовремя.  ...
# 4      У абаперов, как правило, все проекты — это кос...
# 5                                                NonNone
# 6             А ты абгрейдил(апгрейдил) виндовс, до 10?
# 7                                            Абдул хач.
# 8                                                NonNone
# 9                                  Тоже что и Аберглау.
# 10     Главную антипремию «за худшее все в литературе...
# 11     И начался тут полный абздольц!  • Сессию перен...
# 12     Из машины вылезли серьёзные лысые пацаны в спо...
# 13     Я купила абик в клуб, завтра первая тренировка...
# 14                                               NonNone
# 15                                               NonNone
# 16     (1) В холле сплошная абитура.  • Видел сегодня...
# 17     Летом в стенах универа ходит много абитухи.  •...
# 18     Главное, если это будет какой-нибудь абориген,...
# 19     Абреки совсем попутали!  - Пойдем их гасить?  ...
# 20                                               NonNone
# 21     Абубу знают все, никто не может его не знать.\...
# 22                                               NonNone
# 23                              Ну ты конечно абуминог.
# 24                       АБУЭМА!!!! Мой барнакл обычно.
# 25     Абыр! Абыр! Мааама дорогая... Нет! Абыр! Вот т...
# 26                                               NonNone
# 27     «Факт в том что ТХ по статам решает, АВ он бол...
# 28     (1) «Продам коневода 74 лвл BlackBird ава роба...
# 29     До 200 пикселей ава будет небольшая чуть больш...
# ...                                                  ...
# 17818              У ЯнГо новое видео, давай посмотрим!
# 17819                                  поищи в яндексе.
# 17820                                            NonNone
# 17821                                            NonNone
# 17822  Сперва такие «я хочу яндере тян» а потом «коко...
# 17823                       - Да прям Яндэрэ\n- Я знаю.
# 17824                      Яникс выпустил новый бэнгер.
# 17825                                            NonNone
# 17826                Проклятые янки,отстойнейшая нация!
# 17827  Хороша рисовка, но ЯННП.  • Я не знаю что дума...
# 17828       Яой подкрался незаметно . Яойные парнишки .
# 17829                              закоренелая яойщица.
# 17830                                            NonNone
# 17831                                            NonNone
# 17832                                            NonNone
# 17833  Такая картинка что аж яплакал.  • ЯплакалЪ, же...
# 17834  Япона мать, что случилось?!  • Япона мать , ну...
# 17835  Зажиточные яппи восседают за столиками сфериче...
# 17836  Решив, что нам непременно нужно проветриться в...
# 17837   Хорошо, когда девушка от природы ярко выглядит.
# 17838  Мне зарплату свежими ярославлями выдали! ( Мне...
# 17839  — Чтобы дома в 9 как штык!  — Ясен пень!  • Во...
# 17840                                            NonNone
# 17841             Учитель: 2+2=4\nУченик:Ясень-пень XD.
# 17842  Я норм зависаю на ясмпе, читаю книги, смотрю ф...
# 17843                                            NonNone
# 17844                         яснапонятно всё с тобой .
# 17845                                            NonNone
# 17846                                            NonNone
# 17847                   Ты согласен ? Нну. Ясный перец!
#
#                                hashtags  \
# 0                      #Социальныесети
# 1                               #Общие
# 2                               #Общие
# 3                               #Общие
# 4                           #Айтишники
# 5                             #Падонки
# 6                 #Айтишники #Интернет
# 7                               #Общие
# 8                               #Общие
# 9                               #Общие
# 10                              #Общие
# 11                              #Общие
# 12                            #Гопники
# 13                              #Общие
# 14                            #Геймеры
# 15                            #Геймеры
# 16                           #Студенты
# 17                           #Студенты
# 18          #Общие #Ролевики #Студенты
# 19                              #Общие
# 20                              #Общие
# 21                              #Аниме
# 22                       #Геймеры #РПГ
# 23                              #Общие
# 24                              #Общие
# 25                              #Общие
# 26                    #Общие #Интернет
# 27                       #РПГ #Линейка
# 28                       #РПГ #Линейка
# 29                           #Интернет
# ...                                 ...
# 17818                #Селеблити-Звезды
# 17819                           #Общие
# 17820                           #Аниме
# 17821                           #Аниме
# 17822                    #Аниме #Общие
# 17823                           #Аниме
# 17824            #Музыка #СлэнгФанатов
# 17825  #Селеблити-Звезды #СлэнгФанатов
# 17826                           #Общие
# 17827                        #Интернет
# 17828                           #Аниме
# 17829                           #Общие
# 17830                           #Общие
# 17831                  #Социальныесети
# 17832                           #Общие
# 17833               #Падонки #Интернет
# 17834                           #Общие
# 17835                           #Общие
# 17836                        #Топонимы
# 17837                           #Общие
# 17838                           #Общие
# 17839                           #Общие
# 17840                           #Общие
# 17841                           #Общие
# 17842                        #Интернет
# 17843                        #Интернет
# 17844                           #Общие
# 17845                           #Общие
# 17846                           #Общие
# 17847                           #Общие
#
#                                                    story  \
# 0      (происхождение второго значения) раздел был до...
# 1                                                NonNone
# 2                                                NonNone
# 3                                                NonNone
# 4        от англ. ABAPer, имеющего ровно то же значение.
# 5                                                NonNone
# 6                         Сфера IT, от EN слова upgrade.
# 7                                                NonNone
# 8                                                NonNone
# 9                                          город Сальск.
# 10                     эвфемизм, созвучие матному слову.
# 11                                               NonNone
# 12                                               NonNone
# 13                                               NonNone
# 14     от англ. ability — способность, возможность, у...
# 15                       От англ. ability - способность.
# 16                                               NonNone
# 17                        Сокр. и искаж. от абитуриенты.
# 18                                               NonNone
# 19                                               NonNone
# 20                                               NonNone
# 21                                         Аоба — Абуба.
# 22     происходит от abuse, в переводе значит «злоупо...
# 23                                               NonNone
# 24                        Во время сливной игры в SA-MP.
# 25                                        Рыба наоборот.
# 26                                               NonNone
# 27       транслитерация англ. аббрев. AW — Abyss Walker.
# 28                                               NonNone
# 29                                               NonNone
# ...                                                  ...
# 17818                                            NonNone
# 17819                                       от названия.
# 17820                             Яп. yandere, deretsun.
# 17821                                            NonNone
# 17822                                            NonNone
# 17823  От япон. яндеру ( 病んでる) - «психическое расстро...
# 17824                                     Русский народ.
# 17825                                            NonNone
# 17826                                            NonNone
# 17827                                            NonNone
# 17828                                    (яп. やおい яои?).
# 17829                                            NonNone
# 17830                                            NonNone
# 17831                                            NonNone
# 17832                                            NonNone
# 17833                                            NonNone
# 17834                                            NonNone
# 17835                                            NonNone
# 17836                                            NonNone
# 17837                                            NonNone
# 17838  От изображения Ярославля на 1000 рублёвой купюре.
# 17839                                            NonNone
# 17840                                            NonNone
# 17841                                            NonNone
# 17842  От абрревиат. «Я Сломал Мамино Пенсне». Вопрос...
# 17843                                            NonNone
# 17844                                            NonNone
# 17845                                            NonNone
# 17846                                      Ясно+Понятно.
# 17847                                            NonNone
#
#                                                 synonyms
# 0                                                NonNone
# 1                                                    да.
# 2                                                NonNone
# 3      Искажение, эвфемизм матероного выражения, из п...
# 4                                                 АБАПер
# 5      абасцака, ицпадстол, ицпадстул, обоссака, пацт...
# 6                                              АПГРЕ́ЙД.
# 7                                                   хас.
# 8                                                NonNone
# 9                                      АбайКалаУмаласаи.
# 10                                         пипец, капец.
# 11     (1), (2) пипец, ппц, каюк, капец,  вешалка, тр...
# 12                                               NonNone
# 13                                               NonNone
# 14                                      абилка, абилити.
# 15                           Способность, умение, навык.
# 16                                        абитуха, абита
# 17                                        абитура, абита
# 18                                               NonNone
# 19                                               NonNone
# 20                                               NonNone
# 21                                               NonNone
# 22                                               NonNone
# 23                                      амеба, тарантул.
# 24                                                 Нету.
# 25                                                 Голм.
# 26                                абузер, абюзер, обюзер
# 27                                                    AW
# 28                                               NonNone
# 29                                               NonNone
# ...                                                  ...
# 17818                                              YanGo
# 17819                                            NonNone
# 17820                                            NonNone
# 17821                                            NonNone
# 17822                                              псих.
# 17823                             Пошляк, извро, маньяк.
# 17824                           Даун, аутис, было, хайп.
# 17825                                            NonNone
# 17826                                        Американец.
# 17827                                               яннп
# 17828  сёнэн-ай(только в нем нет так сказать "сцен +1...
# 17829                                            NonNone
# 17830                                            NonNone
# 17831                                            NonNone
# 17832                                               яппи
# 17833            я плакалъ, я плакаль, яплакал, я плакал
# 17834  ё-моё, ёпрст, ёклмн, ёхарный бабай, японский г...
# 17835                                                япи
# 17836                                            NonNone
# 17837                                 классно, суперово.
# 17838                                     косарь, косой.
# 17839                                         ясень пень
# 17840                                            NonNone
# 17841                                        ясень-пень.
# 17842                                            NonNone
# 17843                                            NonNone
# 17844                                            NonNone
# 17845                                           Понятно.
# 17846                                            NonNone
# 17847                                         ясен перец
#
# [16751 rows x 8 columns]

# %%
fulldict.to_csv("fullDict.csv", sep=',', index=False)

# %%
fulldict = pd.read_csv("fullDict.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-79b9e44b8ac8> in <module>()
# ----> 1 fulldict = pd.read_csv("fullDict.csv")
#
# NameError: name 'pd' is not defined
